# %%
#import relevant libraries
import sys
import os
import glob

import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import datetime as dt8
import math
import matplotlib.pyplot as plt
import decimal

import dabest
import NLCLIMB

#NOTE: SUPPRESSES WARNINGS!

import warnings

warnings.simplefilter(action="ignore", category=RuntimeWarning)
#warnings.simplefilter(action="default", category=RuntimeWarning)
# Out:
# Pre-compiling numba functions for DABEST...
# Compiling numba functions: 100%|██████████| 11/11 [00:00<00:00, 16.98it/s]
# Numba compilation complete!

# %%
listofgenotypes = ["MB399B x Chrimson2", "SS67662 x Chrimson2", "SS67741 x Chrimson2", "SS01298 x Chrimson2"]

 
wt = "w1118"

path0 = "C:\\Users\\lnico\\"
pathhome = "D:\\"
pathlab = "C:\\Users\\User\\"
pathoffice = "C:\\Users\\Star\\"
specifiedpath = pathhome

# %%
for line in listofgenotypes:
    driver, responder = line.split(' x ')

    mainpath = "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\DATA\\Falling\\Falling_" + str(responder) + "\\"
    savefolder = specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\Data Compilation\\Falling_NEW"

    openPath = specifiedpath + mainpath
    filename = openPath + driver + " x " + responder
    files = os.listdir(openPath)

    print(filename)

    df_control, fpscontrol = NLCLIMB.control(filename, wt)
    df_expt, fpsexpt = NLCLIMB.trans(filename, driver, wt)

    print("Control fps:", fpscontrol, "||Control size:", df_control.shape)
    print("EXPT fps:", fpsexpt, "||EXPT size:", df_expt.shape)
    print("n's for control: ", (len(df_control.columns)-2)*0.5)
    print("n's for expt: ", (len(df_expt.columns)-2)*0.5)

    df_control.to_csv(savefolder+"\\"+wt+"_"+ driver + " x " + responder +'.csv')
    df_expt.to_csv(savefolder+"\\"+ driver + " x " + responder +'.csv')

    print(savefolder+"\\"+wt+"_"+ driver + " x " + responder +'.csv')
    print("COMPLETED!!")
# Out:
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\Falling\Falling_Chrimson2\MB399B x Chrimson2
# Control fps: 5 ||Control size: (330, 508)
# EXPT fps: 5 ||EXPT size: (330, 192)
# n's for control:  253.0
# n's for expt:  95.0
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\Data Compilation\Falling_NEW\w1118_MB399B x Chrimson2.csv
# COMPLETED!!
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\Falling\Falling_Chrimson2\SS67662 x Chrimson2
# Control fps: 5 ||Control size: (330, 328)
# EXPT fps: 5 ||EXPT size: (330, 348)
# n's for control:  163.0
# n's for expt:  173.0
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\Data Compilation\Falling_NEW\w1118_SS67662 x Chrimson2.csv
# COMPLETED!!
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\Falling\Falling_Chrimson2\SS67741 x Chrimson2
# Control fps: 5 ||Control size: (330, 418)
# EXPT fps: 5 ||EXPT size: (330, 156)
# n's for control:  208.0
# n's for expt:  77.0
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\Data Compilation\Falling_NEW\w1118_SS67741 x Chrimson2.csv
# COMPLETED!!
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\Falling\Falling_Chrimson2\SS01298 x Chrimson2
# Control fps: 5 ||Control size: (330, 602)
# EXPT fps: 5 ||EXPT size: (330, 70)
# n's for control:  300.0
# n's for expt:  34.0
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\Data Compilation\Falling_NEW\w1118_SS01298 x Chrimson2.csv
# COMPLETED!!
